# %%
def printHelloWorld():
    print("Hello worldz")

printHelloWorld()
# Out:
# Hello worldz

# %%
def Addition(a,b):
    add = a+b
    print("Addition of 2 values :", add)
    
Addition(10,12)
# Out:
# Addition of 2 values : 22

# %%
def calculation(a,b):
    add = a+b
    sub = a-b
    print("Addition of 2 values :", add)
    print("Subtraction of 2 values :", sub)
    
calculation(10,12)
# Out:
# Addition of 2 values : 22
# Subtraction of 2 values : -2

# %%
list = [1,2,3,4,5]

def addMe(list):
    add = 0
    for i in list:
        add = add+i
    return add, add/2
    
print(addMe(list))
# Out:
# (15, 7.5)

# %%
def Func(food):
    print("Fruits are available now :", fruit)
    return fruit

fruit = ['Banana','Apple', 'Jerry']

Func(fruit)
# Out:
# Fruits are available now : ['Banana', 'Apple', 'Jerry']
# ['Banana', 'Apple', 'Jerry']

# %%
def my_func(food):
    for i in fruit:
        print(i)

fruit = ["Banana","Apple", 'Jerry']

Func(fruit)
# Out:
# Fruits are available now : ['Banana', 'Apple', 'Jerry']
# ['Banana', 'Apple', 'Jerry']
